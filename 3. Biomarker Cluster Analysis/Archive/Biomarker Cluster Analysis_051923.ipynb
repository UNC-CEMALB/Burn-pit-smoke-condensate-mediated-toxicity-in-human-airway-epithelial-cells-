# %%
Output = ('/Users/alexis/Library/CloudStorage/OneDrive-UniversityofNorthCarolinaatChapelHill/CEMALB_DataAnalysisPM/Projects/P1011. Emission Mixtures/P1011.3. Analyses/P1011.3.2. Biomarker Cluster Analysis/Output')
cur_date = "051923"

library(readxl)
library(tidyverse)
library(reshape2)
library(factoextra)
library(cowplot)

# reading in files
mRNA_df = data.frame(read_excel("Input/Imputed_mRNA_Data_042623.xlsx"))
proteomics_5_df = data.frame(read_excel("Input/Proteomics_Data_5ug_040423.xlsx", sheet = 2))
proteomics_25_df = data.frame(read_excel("Input/Proteomics_Data_25ug_040423.xlsx", sheet = 2))
cytokine_df = data.frame(read_excel("Input/Cytokine_Data_050423.xlsx", sheet = 2))
mRNA_wilcoxon_df = data.frame(read_excel("Input/042723_mRNA_Wilcoxon_Results.xlsx"))
proteomics_wilcoxon_df = data.frame(read_excel("Input/050223_Proteomics_Wilcoxon_Results.xlsx"))
cytokine_wilcoxon_df = data.frame(read_excel("Input/050423_Cytokine_Wilcoxon_Results.xlsx"))
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0     ✔ purrr   1.0.1
# ✔ tibble  3.2.1     ✔ dplyr   1.1.2
# ✔ tidyr   1.2.1     ✔ stringr 1.4.1
# ✔ readr   2.1.2     ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Attaching package: ‘reshape2’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths
#
#
# Welcome! Want to learn more? See two factoextra-related books at https://goo.gl/ve3WBa
#
# Warning message:
# “Expecting numeric in E1226 / R1226C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1227 / R1227C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1228 / R1228C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1229 / R1229C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1230 / R1230C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1231 / R1231C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1232 / R1232C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1233 / R1233C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1234 / R1234C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1235 / R1235C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1236 / R1236C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1237 / R1237C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1238 / R1238C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1239 / R1239C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1240 / R1240C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1241 / R1241C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1242 / R1242C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1243 / R1243C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1244 / R1244C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1245 / R1245C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1246 / R1246C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1247 / R1247C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1248 / R1248C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1249 / R1249C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1250 / R1250C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1251 / R1251C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1252 / R1252C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1253 / R1253C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1254 / R1254C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1255 / R1255C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1256 / R1256C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1257 / R1257C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1258 / R1258C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1259 / R1259C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1260 / R1260C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1261 / R1261C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1262 / R1262C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1263 / R1263C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1264 / R1264C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1265 / R1265C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1266 / R1266C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1267 / R1267C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1268 / R1268C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1269 / R1269C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1270 / R1270C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1271 / R1271C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1272 / R1272C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1273 / R1273C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1274 / R1274C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1275 / R1275C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1276 / R1276C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1277 / R1277C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1278 / R1278C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1279 / R1279C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1280 / R1280C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1281 / R1281C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1282 / R1282C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1283 / R1283C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1284 / R1284C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1285 / R1285C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1286 / R1286C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1287 / R1287C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1288 / R1288C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1289 / R1289C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1290 / R1290C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1291 / R1291C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1292 / R1292C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1293 / R1293C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1294 / R1294C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1295 / R1295C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1296 / R1296C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1297 / R1297C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1298 / R1298C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1299 / R1299C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1300 / R1300C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1301 / R1301C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1302 / R1302C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1303 / R1303C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1304 / R1304C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1305 / R1305C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1306 / R1306C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1307 / R1307C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1308 / R1308C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1309 / R1309C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1310 / R1310C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1311 / R1311C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1312 / R1312C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1313 / R1313C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1314 / R1314C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1315 / R1315C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1316 / R1316C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1317 / R1317C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1318 / R1318C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1319 / R1319C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1320 / R1320C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1321 / R1321C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1322 / R1322C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1323 / R1323C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1324 / R1324C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1325 / R1325C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1326 / R1326C5: got 'NA'”
# Warning message:
# “Expecting numeric in E1327 / R1327C5: got 'NA'”
# Warning message:
# “Coercing text to numeric in F1275 / R1275C6: 'NaN'”
# Warning message:
# “Expecting numeric in G1275 / R1275C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3046 / R3046C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3046 / R3046C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3052 / R3052C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3052 / R3052C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3163 / R3163C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3163 / R3163C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3230 / R3230C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3230 / R3230C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3436 / R3436C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3436 / R3436C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3439 / R3439C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3439 / R3439C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3441 / R3441C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3441 / R3441C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3498 / R3498C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3498 / R3498C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3499 / R3499C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3499 / R3499C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3519 / R3519C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3519 / R3519C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3525 / R3525C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3525 / R3525C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3554 / R3554C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3554 / R3554C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3589 / R3589C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3589 / R3589C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3713 / R3713C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3713 / R3713C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3726 / R3726C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3726 / R3726C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3744 / R3744C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3744 / R3744C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3745 / R3745C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3745 / R3745C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3764 / R3764C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3764 / R3764C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3768 / R3768C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3768 / R3768C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3769 / R3769C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3769 / R3769C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3790 / R3790C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3790 / R3790C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3802 / R3802C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3802 / R3802C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3803 / R3803C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3803 / R3803C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3832 / R3832C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3832 / R3832C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3848 / R3848C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3848 / R3848C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3858 / R3858C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3858 / R3858C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3866 / R3866C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3866 / R3866C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3884 / R3884C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3884 / R3884C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3888 / R3888C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3888 / R3888C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3933 / R3933C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3933 / R3933C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3949 / R3949C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3949 / R3949C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3964 / R3964C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3964 / R3964C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3977 / R3977C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3977 / R3977C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3985 / R3985C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3985 / R3985C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3986 / R3986C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3986 / R3986C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3988 / R3988C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3988 / R3988C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F3992 / R3992C6: 'NaN'”
# Warning message:
# “Expecting numeric in G3992 / R3992C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F4008 / R4008C6: 'NaN'”
# Warning message:
# “Expecting numeric in G4008 / R4008C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F4010 / R4010C6: 'NaN'”
# Warning message:
# “Expecting numeric in G4010 / R4010C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F4011 / R4011C6: 'NaN'”
# Warning message:
# “Expecting numeric in G4011 / R4011C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F4012 / R4012C6: 'NaN'”
# Warning message:
# “Expecting numeric in G4012 / R4012C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F4020 / R4020C6: 'NaN'”
# Warning message:
# “Expecting numeric in G4020 / R4020C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F4024 / R4024C6: 'NaN'”
# Warning message:
# “Expecting numeric in G4024 / R4024C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F4026 / R4026C6: 'NaN'”
# Warning message:
# “Expecting numeric in G4026 / R4026C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F4028 / R4028C6: 'NaN'”
# Warning message:
# “Expecting numeric in G4028 / R4028C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F4029 / R4029C6: 'NaN'”
# Warning message:
# “Expecting numeric in G4029 / R4029C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F4033 / R4033C6: 'NaN'”
# Warning message:
# “Expecting numeric in G4033 / R4033C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F4043 / R4043C6: 'NaN'”
# Warning message:
# “Expecting numeric in G4043 / R4043C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F4044 / R4044C6: 'NaN'”
# Warning message:
# “Expecting numeric in G4044 / R4044C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F4046 / R4046C6: 'NaN'”
# Warning message:
# “Expecting numeric in G4046 / R4046C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F4047 / R4047C6: 'NaN'”
# Warning message:
# “Expecting numeric in G4047 / R4047C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F4048 / R4048C6: 'NaN'”
# Warning message:
# “Expecting numeric in G4048 / R4048C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F4049 / R4049C6: 'NaN'”
# Warning message:
# “Expecting numeric in G4049 / R4049C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F4056 / R4056C6: 'NaN'”
# Warning message:
# “Expecting numeric in G4056 / R4056C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F4064 / R4064C6: 'NaN'”
# Warning message:
# “Expecting numeric in G4064 / R4064C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F4067 / R4067C6: 'NaN'”
# Warning message:
# “Expecting numeric in G4067 / R4067C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F4068 / R4068C6: 'NaN'”
# Warning message:
# “Expecting numeric in G4068 / R4068C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F4069 / R4069C6: 'NaN'”
# Warning message:
# “Expecting numeric in G4069 / R4069C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F4070 / R4070C6: 'NaN'”
# Warning message:
# “Expecting numeric in G4070 / R4070C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F4074 / R4074C6: 'NaN'”
# Warning message:
# “Expecting numeric in G4074 / R4074C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F6464 / R6464C6: 'NaN'”
# Warning message:
# “Expecting numeric in G6464 / R6464C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F6635 / R6635C6: 'NaN'”
# Warning message:
# “Expecting numeric in G6635 / R6635C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F6827 / R6827C6: 'NaN'”
# Warning message:
# “Expecting numeric in G6827 / R6827C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F7254 / R7254C6: 'NaN'”
# Warning message:
# “Expecting numeric in G7254 / R7254C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F7848 / R7848C6: 'NaN'”
# Warning message:
# “Expecting numeric in G7848 / R7848C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F7890 / R7890C6: 'NaN'”
# Warning message:
# “Expecting numeric in G7890 / R7890C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8036 / R8036C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8036 / R8036C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8039 / R8039C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8039 / R8039C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8072 / R8072C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8072 / R8072C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8073 / R8073C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8073 / R8073C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8080 / R8080C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8080 / R8080C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8081 / R8081C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8081 / R8081C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8095 / R8095C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8095 / R8095C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8135 / R8135C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8135 / R8135C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8138 / R8138C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8138 / R8138C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8142 / R8142C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8142 / R8142C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8171 / R8171C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8171 / R8171C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8180 / R8180C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8180 / R8180C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8188 / R8188C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8188 / R8188C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8189 / R8189C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8189 / R8189C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8249 / R8249C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8249 / R8249C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8250 / R8250C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8250 / R8250C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8253 / R8253C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8253 / R8253C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8257 / R8257C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8257 / R8257C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8260 / R8260C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8260 / R8260C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8271 / R8271C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8271 / R8271C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8284 / R8284C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8284 / R8284C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8290 / R8290C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8290 / R8290C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8298 / R8298C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8298 / R8298C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8299 / R8299C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8299 / R8299C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8311 / R8311C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8311 / R8311C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8314 / R8314C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8314 / R8314C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8315 / R8315C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8315 / R8315C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8339 / R8339C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8339 / R8339C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8344 / R8344C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8344 / R8344C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8355 / R8355C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8355 / R8355C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8366 / R8366C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8366 / R8366C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8367 / R8367C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8367 / R8367C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8376 / R8376C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8376 / R8376C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8377 / R8377C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8377 / R8377C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8381 / R8381C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8381 / R8381C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8382 / R8382C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8382 / R8382C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8383 / R8383C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8383 / R8383C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8388 / R8388C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8388 / R8388C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8389 / R8389C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8389 / R8389C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F8390 / R8390C6: 'NaN'”
# Warning message:
# “Expecting numeric in G8390 / R8390C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F10584 / R10584C6: 'NaN'”
# Warning message:
# “Expecting numeric in G10584 / R10584C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F11206 / R11206C6: 'NaN'”
# Warning message:
# “Expecting numeric in G11206 / R11206C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F11352 / R11352C6: 'NaN'”
# Warning message:
# “Expecting numeric in G11352 / R11352C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F11406 / R11406C6: 'NaN'”
# Warning message:
# “Expecting numeric in G11406 / R11406C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F11407 / R11407C6: 'NaN'”
# Warning message:
# “Expecting numeric in G11407 / R11407C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F11442 / R11442C6: 'NaN'”
# Warning message:
# “Expecting numeric in G11442 / R11442C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F11546 / R11546C6: 'NaN'”
# Warning message:
# “Expecting numeric in G11546 / R11546C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F11553 / R11553C6: 'NaN'”
# Warning message:
# “Expecting numeric in G11553 / R11553C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F11620 / R11620C6: 'NaN'”
# Warning message:
# “Expecting numeric in G11620 / R11620C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F11730 / R11730C6: 'NaN'”
# Warning message:
# “Expecting numeric in G11730 / R11730C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F11731 / R11731C6: 'NaN'”
# Warning message:
# “Expecting numeric in G11731 / R11731C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F11831 / R11831C6: 'NaN'”
# Warning message:
# “Expecting numeric in G11831 / R11831C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F11888 / R11888C6: 'NaN'”
# Warning message:
# “Expecting numeric in G11888 / R11888C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F11979 / R11979C6: 'NaN'”
# Warning message:
# “Expecting numeric in G11979 / R11979C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12045 / R12045C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12045 / R12045C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12098 / R12098C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12098 / R12098C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12099 / R12099C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12099 / R12099C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12116 / R12116C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12116 / R12116C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12120 / R12120C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12120 / R12120C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12153 / R12153C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12153 / R12153C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12157 / R12157C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12157 / R12157C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12159 / R12159C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12159 / R12159C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12187 / R12187C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12187 / R12187C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12189 / R12189C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12189 / R12189C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12190 / R12190C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12190 / R12190C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12191 / R12191C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12191 / R12191C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12193 / R12193C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12193 / R12193C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12202 / R12202C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12202 / R12202C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12213 / R12213C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12213 / R12213C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12256 / R12256C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12256 / R12256C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12268 / R12268C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12268 / R12268C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12273 / R12273C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12273 / R12273C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12277 / R12277C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12277 / R12277C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12295 / R12295C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12295 / R12295C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12296 / R12296C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12296 / R12296C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12300 / R12300C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12300 / R12300C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12301 / R12301C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12301 / R12301C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12318 / R12318C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12318 / R12318C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12321 / R12321C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12321 / R12321C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12323 / R12323C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12323 / R12323C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12332 / R12332C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12332 / R12332C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12339 / R12339C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12339 / R12339C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12350 / R12350C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12350 / R12350C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12354 / R12354C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12354 / R12354C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12356 / R12356C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12356 / R12356C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12363 / R12363C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12363 / R12363C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12367 / R12367C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12367 / R12367C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12380 / R12380C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12380 / R12380C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12382 / R12382C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12382 / R12382C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12384 / R12384C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12384 / R12384C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12385 / R12385C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12385 / R12385C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12386 / R12386C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12386 / R12386C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12400 / R12400C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12400 / R12400C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12402 / R12402C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12402 / R12402C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12419 / R12419C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12419 / R12419C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12421 / R12421C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12421 / R12421C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12423 / R12423C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12423 / R12423C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12436 / R12436C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12436 / R12436C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12439 / R12439C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12439 / R12439C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12440 / R12440C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12440 / R12440C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12444 / R12444C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12444 / R12444C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12446 / R12446C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12446 / R12446C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12449 / R12449C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12449 / R12449C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12450 / R12450C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12450 / R12450C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12452 / R12452C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12452 / R12452C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12453 / R12453C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12453 / R12453C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12459 / R12459C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12459 / R12459C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12460 / R12460C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12460 / R12460C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12463 / R12463C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12463 / R12463C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12464 / R12464C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12464 / R12464C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12466 / R12466C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12466 / R12466C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F12467 / R12467C6: 'NaN'”
# Warning message:
# “Expecting numeric in G12467 / R12467C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F15025 / R15025C6: 'NaN'”
# Warning message:
# “Expecting numeric in G15025 / R15025C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F15049 / R15049C6: 'NaN'”
# Warning message:
# “Expecting numeric in G15049 / R15049C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F15217 / R15217C6: 'NaN'”
# Warning message:
# “Expecting numeric in G15217 / R15217C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F15324 / R15324C6: 'NaN'”
# Warning message:
# “Expecting numeric in G15324 / R15324C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F15370 / R15370C6: 'NaN'”
# Warning message:
# “Expecting numeric in G15370 / R15370C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F15520 / R15520C6: 'NaN'”
# Warning message:
# “Expecting numeric in G15520 / R15520C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F15610 / R15610C6: 'NaN'”
# Warning message:
# “Expecting numeric in G15610 / R15610C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F15611 / R15611C6: 'NaN'”
# Warning message:
# “Expecting numeric in G15611 / R15611C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F15644 / R15644C6: 'NaN'”
# Warning message:
# “Expecting numeric in G15644 / R15644C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F15723 / R15723C6: 'NaN'”
# Warning message:
# “Expecting numeric in G15723 / R15723C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F15814 / R15814C6: 'NaN'”
# Warning message:
# “Expecting numeric in G15814 / R15814C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F15866 / R15866C6: 'NaN'”
# Warning message:
# “Expecting numeric in G15866 / R15866C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16242 / R16242C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16242 / R16242C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16280 / R16280C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16280 / R16280C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16394 / R16394C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16394 / R16394C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16431 / R16431C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16431 / R16431C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16452 / R16452C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16452 / R16452C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16468 / R16468C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16468 / R16468C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16469 / R16469C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16469 / R16469C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16470 / R16470C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16470 / R16470C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16491 / R16491C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16491 / R16491C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16495 / R16495C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16495 / R16495C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16516 / R16516C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16516 / R16516C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16528 / R16528C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16528 / R16528C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16532 / R16532C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16532 / R16532C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16562 / R16562C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16562 / R16562C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16579 / R16579C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16579 / R16579C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16583 / R16583C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16583 / R16583C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16623 / R16623C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16623 / R16623C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16643 / R16643C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16643 / R16643C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16650 / R16650C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16650 / R16650C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16667 / R16667C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16667 / R16667C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16669 / R16669C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16669 / R16669C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16670 / R16670C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16670 / R16670C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16674 / R16674C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16674 / R16674C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16687 / R16687C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16687 / R16687C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16689 / R16689C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16689 / R16689C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16701 / R16701C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16701 / R16701C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16706 / R16706C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16706 / R16706C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16711 / R16711C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16711 / R16711C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16721 / R16721C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16721 / R16721C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16736 / R16736C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16736 / R16736C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16742 / R16742C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16742 / R16742C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16743 / R16743C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16743 / R16743C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16758 / R16758C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16758 / R16758C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16759 / R16759C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16759 / R16759C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16760 / R16760C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16760 / R16760C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16762 / R16762C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16762 / R16762C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16766 / R16766C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16766 / R16766C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16768 / R16768C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16768 / R16768C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16772 / R16772C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16772 / R16772C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16774 / R16774C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16774 / R16774C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16775 / R16775C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16775 / R16775C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16776 / R16776C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16776 / R16776C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16777 / R16777C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16777 / R16777C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16778 / R16778C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16778 / R16778C7: got 'NA'”
# Warning message:
# “Coercing text to numeric in F16780 / R16780C6: 'NaN'”
# Warning message:
# “Expecting numeric in G16780 / R16780C7: got 'NA'”

# %%
head(mRNA_df)
head(proteomics_25_df)
head(cytokine_df)
head(mRNA_wilcoxon_df)
# Out:
#   Subject_ID Condensate Burn_Condition Concentration Time_Point mRNA
# 1 M_6        PBS        PBS            NA            24         HMOX1
# 2 M_6        PBS        PBS            NA            24         ALDH3A1
# 3 M_6        PBS        PBS            NA            24         CXCL1
# 4 M_6        PBS        PBS            NA            24         CXCR1
# 5 M_6        PBS        PBS            NA            24         GCLC
# 6 M_6        PBS        PBS            NA            24         GCLM
#   ddCT_pslog2
# 1 4.871886
# 2 4.837012
# 3 4.822372
# 4 3.940873
# 5 4.863186
# 6 4.834127
#   Subject_No Subject_ID Protein_Accession Gene_Name
# 1 1          F_1        CO3_HUMAN         C3
# 2 2          M_2        CO3_HUMAN         C3
# 3 3          M_3        CO3_HUMAN         C3
# 4 4          F_4        CO3_HUMAN         C3
# 5 5          F_5        CO3_HUMAN         C3
# 6 6          M_6        CO3_HUMAN         C3
#   Description                                           Condensate
# 1 Complement C3 OS=Homo sapiens OX=9606 GN=C3 PE=1 SV=2 C
# 2 Complement C3 OS=Homo sapiens OX=9606 GN=C3 PE=1 SV=2 C
# 3 Complement C3 OS=Homo sapiens OX=9606 GN=C3 PE=1 SV=2 C
# 4 Complement C3 OS=Homo sapiens OX=9606 GN=C3 PE=1 SV=2 C
# 5 Complement C3 OS=Homo sapiens OX=9606 GN=C3 PE=1 SV=2 C
# 6 Complement C3 OS=Homo sapiens OX=9606 GN=C3 PE=1 SV=2 C
#   Burn_Condition Concentration Intensity  Intensity_pslog2
# 1 F              25            1488600000 30.47131
# 2 F              25            3806600000 31.82586
# 3 F              25            3900000000 31.86083
# 4 F              25            5373200000 32.32313
# 5 F              25            2595200000 31.27320
# 6 F              25            5780700000 32.42860
#   Subject_No Subject_ID Condensate Burn_Condition Condensate_Conc Cytokine
# 1 1          F_1        C          F               1              Eotaxin3
# 2 1          F_1        C          F              25              Eotaxin3
# 3 1          F_1        C          F               5              Eotaxin3
# 4 1          F_1        C          S               1              Eotaxin3
# 5 1          F_1        C          S              25              Eotaxin3
# 6 1          F_1        C          S               5              Eotaxin3
#   Cytokine_Conc Cytokine_Conc_pslog2
# 1 21.750958     4.507855
# 2 11.624224     3.658123
# 3 17.828714     4.234863
# 4 22.798534     4.572801
# 5 10.342567     3.503675
# 6  9.140652     3.342078
#   mRNA    Condensate Comparison          Concentration Time.Point Statistic
# 1 HMOX1   Cardboard  Control vs. Flaming 1             24          6
# 2 HMOX1   Plastic    Control vs. Flaming 1             24          6
# 3 ALDH3A1 Cardboard  Control vs. Flaming 1             24         10
# 4 ALDH3A1 Plastic    Control vs. Flaming 1             24          2
# 5 CXCL1   Cardboard  Control vs. Flaming 1             24          7
# 6 CXCL1   Plastic    Control vs. Flaming 1             24         10
#   P.Value P.Adj
# 1 0.43750 0.5937500
# 2 0.43750 1.0000000
# 3 1.00000 0.6286765
# 4 0.09375 0.6286765
# 5 0.56250 0.1484375
# 6 1.00000 0.3710938

# %% [markdown]
# This analysis will use PCA to explore if there are clusters of biomarkers based on the condensate or burn condition. First will identify the biomarkers that are significant (p value < 0.05).

# %%
sig_mRNA_df = mRNA_wilcoxon_df %>%
    filter(P.Value < 0.05)
sig_mRNAs = unique(sig_mRNA_df$mRNA)

sig_proteomics_df = proteomics_wilcoxon_df %>%
    filter(P.Value < 0.05)
sig_proteins = unique(sig_proteomics_df$Protein)

sig_cytokine_df = cytokine_wilcoxon_df %>%
    filter(P.Value < 0.05)
sig_cytokines = unique(sig_cytokine_df$Cytokine)

# %%
wider_mRNA_df = mRNA_df %>%
    # creating a column that denotes the biomarker
    mutate(Biomarker = "mRNA") %>%
    # creating sample ids
    unite("SampleID", c(colnames(mRNA_df)[c(6,2:5)]), remove = FALSE) %>%
    pivot_wider(names_from = "Subject_ID", values_from = "ddCT_pslog2") %>%
    column_to_rownames(var = "SampleID") %>%
    # keeping sig mRNAs only
    filter(mRNA %in% sig_mRNAs)


# rearranging columns
wider_mRNA_df = wider_mRNA_df[,c(6,9:12,8,7,5,1:4)]
head(wider_mRNA_df)
# Out:
#                       Biomarker F_1      M_2      M_3      F_4      F_5
# HMOX1_PBS_PBS_NA_24   mRNA      4.774787 4.774766 4.774955 4.774918 4.774656
# ALDH3A1_PBS_PBS_NA_24 mRNA      4.790564 4.815891 4.783329 4.821705 4.826226
# CXCR1_PBS_PBS_NA_24   mRNA      3.956375 3.880202 3.981948 3.919197 3.964669
# GCLC_PBS_PBS_NA_24    mRNA      4.851443 4.858772 4.865541 4.862229 4.871636
# GCLM_PBS_PBS_NA_24    mRNA      4.822743 4.829920 4.836289 4.837137 4.840402
# GMCSF2_PBS_PBS_NA_24  mRNA      4.582481 4.568797 4.562426 4.462491 4.525502
#                       M_6      mRNA    Condensate Burn_Condition Concentration
# HMOX1_PBS_PBS_NA_24   4.871886 HMOX1   PBS        PBS            NA
# ALDH3A1_PBS_PBS_NA_24 4.837012 ALDH3A1 PBS        PBS            NA
# CXCR1_PBS_PBS_NA_24   3.940873 CXCR1   PBS        PBS            NA
# GCLC_PBS_PBS_NA_24    4.863186 GCLC    PBS        PBS            NA
# GCLM_PBS_PBS_NA_24    4.834127 GCLM    PBS        PBS            NA
# GMCSF2_PBS_PBS_NA_24  4.471997 GMCSF2  PBS        PBS            NA
#                       Time_Point
# HMOX1_PBS_PBS_NA_24   24
# ALDH3A1_PBS_PBS_NA_24 24
# CXCR1_PBS_PBS_NA_24   24
# GCLC_PBS_PBS_NA_24    24
# GCLM_PBS_PBS_NA_24    24
# GMCSF2_PBS_PBS_NA_24  24

# %%
wider_proteomics_25_df = proteomics_25_df %>%
    # creating a column that denotes the biomarker
    mutate(Biomarker = "Protein") %>%
    # creating sample ids
    unite("Sample_ID", c(colnames(proteomics_25_df)[c(3,6:8)]), remove = FALSE) %>%
    select(-colnames(proteomics_25_df)[c(1,4,5,9)]) %>%
    pivot_wider(names_from = "Subject_ID", values_from = "Intensity_pslog2") 

wider_proteomics_5_df = proteomics_5_df %>%
    # creating a column that denotes the biomarker
    mutate(Biomarker = "Protein") %>%
    # creating sample ids
    unite("Sample_ID", c(colnames(proteomics_5_df)[c(3,6:8)]), remove = FALSE) %>%
    select(-colnames(proteomics_5_df)[c(1,4,5,9)]) %>%
    pivot_wider(names_from = "Subject_ID", values_from = "Intensity_pslog2")

# creating 1 df
wider_proteomics_df = rbind(wider_proteomics_25_df, wider_proteomics_5_df) %>%
    column_to_rownames(var = "Sample_ID") %>%
    # keeping sig proteins only
    filter(Protein_Accession %in% sig_proteins)

# rearranging columns
wider_proteomics_df = wider_proteomics_df[,c(5:11,1:4)]

head(wider_proteomics_df)
# Out:
#                        Biomarker F_1      M_2      M_3      F_4      F_5
# TBB4B_HUMAN_C_F_25     Protein   31.51747 33.79421 30.81291 30.62932 30.50085
# TBB4B_HUMAN_C_S_25     Protein   31.88012 32.88696 31.85898 33.88057 30.21292
# TBB4B_HUMAN_PBS_PBS_25 Protein   28.91536 31.71510 29.50304 31.33186 27.16911
# TBB4B_HUMAN_P_F_25     Protein   30.56047 33.77353 30.37689 32.99115 30.51305
# TBB4B_HUMAN_P_S_25     Protein   31.25316 32.30236 32.47504 31.95640 29.57544
# K2C5_HUMAN_C_F_25      Protein   32.15068 31.70656 31.70161 32.32136 32.45985
#                        M_6      Protein_Accession Condensate Burn_Condition
# TBB4B_HUMAN_C_F_25     30.52943 TBB4B_HUMAN       C          F
# TBB4B_HUMAN_C_S_25     29.90153 TBB4B_HUMAN       C          S
# TBB4B_HUMAN_PBS_PBS_25 30.66687 TBB4B_HUMAN       PBS        PBS
# TBB4B_HUMAN_P_F_25     31.01199 TBB4B_HUMAN       P          F
# TBB4B_HUMAN_P_S_25     30.69029 TBB4B_HUMAN       P          S
# K2C5_HUMAN_C_F_25      31.51695 K2C5_HUMAN        C          F
#                        Concentration
# TBB4B_HUMAN_C_F_25     25
# TBB4B_HUMAN_C_S_25     25
# TBB4B_HUMAN_PBS_PBS_25 25
# TBB4B_HUMAN_P_F_25     25
# TBB4B_HUMAN_P_S_25     25
# K2C5_HUMAN_C_F_25      25

# %%
wider_cytokine_df = cytokine_df %>%
    # creating a column that denotes the biomarker
    mutate(Biomarker = "Cytokine") %>%
    # creating sample ids
    unite("SampleID", c(colnames(cytokine_df)[c(6,3:5)]), remove = FALSE) %>%
    select(-colnames(cytokine_df)[c(1,7)]) %>%
    pivot_wider(names_from = "Subject_ID", values_from = "Cytokine_Conc_pslog2") %>%
    column_to_rownames(var = "SampleID") %>%
    # keeping sig cytokine only
    filter(Cytokine %in% sig_cytokines)

# rearranging columns
wider_cytokine_df = wider_cytokine_df[,c(5:11,4,1:3)]
head(wider_cytokine_df)
# Out:
#             Biomarker F_1      M_2      M_3      F_4      F_5      M_6
# IL13_C_F_1  Cytokine  3.962360 3.748662 4.754599 5.191672 4.881900 5.338952
# IL13_C_F_25 Cytokine  4.792873 3.739843 4.688516 5.406573 5.284892 6.036998
# IL13_C_F_5  Cytokine  4.374822 4.034140 4.826357 5.303577 5.194404 5.740297
# IL13_C_S_1  Cytokine  1.808082 3.286551 4.839928 4.819852 5.708900 5.410493
# IL13_C_S_25 Cytokine  3.467581 3.999339 5.506292 5.739518 5.719180 5.735221
# IL13_C_S_5  Cytokine  2.188359 3.126513 5.152505 4.522313 5.460618 5.607200
#             Cytokine Condensate Burn_Condition Condensate_Conc
# IL13_C_F_1  IL13     C          F               1
# IL13_C_F_25 IL13     C          F              25
# IL13_C_F_5  IL13     C          F               5
# IL13_C_S_1  IL13     C          S               1
# IL13_C_S_25 IL13     C          S              25
# IL13_C_S_5  IL13     C          S               5

# %%
# creating a wider df for all data
wider_df = rbind(wider_mRNA_df[,1:7], wider_proteomics_df[,1:7], wider_cytokine_df[,1:7])
head(wider_df)
# Out:
#                       Biomarker F_1      M_2      M_3      F_4      F_5
# HMOX1_PBS_PBS_NA_24   mRNA      4.774787 4.774766 4.774955 4.774918 4.774656
# ALDH3A1_PBS_PBS_NA_24 mRNA      4.790564 4.815891 4.783329 4.821705 4.826226
# CXCR1_PBS_PBS_NA_24   mRNA      3.956375 3.880202 3.981948 3.919197 3.964669
# GCLC_PBS_PBS_NA_24    mRNA      4.851443 4.858772 4.865541 4.862229 4.871636
# GCLM_PBS_PBS_NA_24    mRNA      4.822743 4.829920 4.836289 4.837137 4.840402
# GMCSF2_PBS_PBS_NA_24  mRNA      4.582481 4.568797 4.562426 4.462491 4.525502
#                       M_6
# HMOX1_PBS_PBS_NA_24   4.871886
# ALDH3A1_PBS_PBS_NA_24 4.837012
# CXCR1_PBS_PBS_NA_24   3.940873
# GCLC_PBS_PBS_NA_24    4.863186
# GCLM_PBS_PBS_NA_24    4.834127
# GMCSF2_PBS_PBS_NA_24  4.471997

# %%
# running pca 
pca_all_data = prcomp(wider_df[,2:7], center = TRUE)

# looking a scree plot to see how much of the variance was captured in first 2 eigenvectors
options(repr.plot.width = 12, repr.plot.height = 7) #changing size
fviz_eig(pca_all_data, addlabels = TRUE)
# Out:
# plot without title

# %%
# pca plot of all data together
options(repr.plot.width = 12, repr.plot.height = 7) # changing size
fviz_pca_ind(pca_all_data, geom.ind = "point", # removes geo ids
             # coloring by biomarker
#             col.ind = factor(as.character(wider_df$Biomarker)), 
#              #adding 95% confidence ellipses for each group
#              addEllipses = TRUE, # Concentration ellipses
#              ellipse.type = "confidence", # now making them concentration ellipses
             repel = TRUE, title = "") +
theme(axis.line = element_line(colour = "black"), # making x and y axes black
      legend.title = element_text(size = 9, face = "bold"),
      legend.text = element_text(size = 8),
      legend.position = 'bottom',
      axis.title = element_text(face = "bold", size = rel(1.1))) # changes axis titles
# Out:
# plot without title

# %%
# creating 1 df with eigenvectors, pslog2 values, condensate, burn condition data
pca_df = data.frame(pca_all_data$x[,1:2]) %>%
               rownames_to_column(var = "Sample_ID") 
more_data_biomarker_df =  rbind(wider_cytokine_df[,1:10] %>% 
               rename(Biomarker_Name = Cytokine), wider_mRNA_df[,1:10] %>% 
                rename(Biomarker_Name = mRNA), 
               wider_proteomics_df[,1:10] %>% 
                rename(Biomarker_Name = Protein_Accession)) %>%
               rownames_to_column(var = "Sample_ID")

full_eigenvector_df = inner_join(pca_df,more_data_biomarker_df)
head(full_eigenvector_df)
# Out:
# Joining with `by = join_by(Sample_ID)`
#   Sample_ID             PC1       PC2      Biomarker F_1      M_2      M_3
# 1 HMOX1_PBS_PBS_NA_24   -37.36476 2.349236 mRNA      4.774787 4.774766 4.774955
# 2 ALDH3A1_PBS_PBS_NA_24 -37.31440 2.356162 mRNA      4.790564 4.815891 4.783329
# 3 CXCR1_PBS_PBS_NA_24   -39.44067 2.488854 mRNA      3.956375 3.880202 3.981948
# 4 GCLC_PBS_PBS_NA_24    -37.19210 2.391160 mRNA      4.851443 4.858772 4.865541
# 5 GCLM_PBS_PBS_NA_24    -37.26235 2.390021 mRNA      4.822743 4.829920 4.836289
# 6 GMCSF2_PBS_PBS_NA_24  -38.00887 2.500145 mRNA      4.582481 4.568797 4.562426
#   F_4      F_5      M_6      Biomarker_Name Condensate Burn_Condition
# 1 4.774918 4.774656 4.871886 HMOX1          PBS        PBS
# 2 4.821705 4.826226 4.837012 ALDH3A1        PBS        PBS
# 3 3.919197 3.964669 3.940873 CXCR1          PBS        PBS
# 4 4.862229 4.871636 4.863186 GCLC           PBS        PBS
# 5 4.837137 4.840402 4.834127 GCLM           PBS        PBS
# 6 4.462491 4.525502 4.471997 GMCSF2         PBS        PBS

# %%
options(repr.plot.width=15, repr.plot.height=8) #changing size
ggplot(data = full_eigenvector_df, aes(x = PC1, y = PC2, color = Burn_Condition)) + 
  geom_point(size = 2) + 
  stat_ellipse(level = 0.95) + # 95% confidence ellipses


  facet_wrap(~Biomarker, scales = "free") + 

  theme_light() + 
  theme(axis.text.x = element_text(vjust = 0.5), #rotating x labels/ moving x labels slightly to the left
        axis.line = element_line(colour="black"), #making x and y axes black
        axis.text = element_text(size = 13), #changing size of x axis labels
        axis.title = element_text(face = "bold", size = rel(1.7)), #changes axis titles
        legend.title = element_text(face = 'bold', size = 17), #changes legend title
        legend.text = element_text(size = 14), #changes legend text
        legend.position = 'bottom',
        legend.background = element_rect(colour = 'black', fill = 'white', linetype = 'solid'),
        strip.text.x = element_text(size = 18, face = "bold"), #changes size of facet x axis 
        strip.text.y = element_text(size = 18, face = "bold")) + #changes size of facet y axis 
  xlab('Dimension 1 (67.5%)') + ylab('Dimension 2 (9.5%)')  #changing axis labels
# Out:
# plot without title

# %%
options(repr.plot.width=15, repr.plot.height=8) #changing size
ggplot(data = full_eigenvector_df, aes(x = PC1, y = PC2, color = Condensate)) + 
  geom_point(size = 2) + 
  stat_ellipse(level = 0.95) + # 95% confidence ellipses

  facet_wrap(~Biomarker, scales = "free") + 

  theme_light() + 
  theme(axis.text.x = element_text(vjust = 0.5), #rotating x labels/ moving x labels slightly to the left
        axis.line = element_line(colour="black"), #making x and y axes black
        axis.text = element_text(size = 13), #changing size of x axis labels
        axis.title = element_text(face = "bold", size = rel(1.7)), #changes axis titles
        legend.title = element_text(face = 'bold', size = 17), #changes legend title
        legend.text = element_text(size = 14), #changes legend text
        legend.position = 'bottom',
        legend.background = element_rect(colour = 'black', fill = 'white', linetype = 'solid'),
        strip.text.x = element_text(size = 18, face = "bold"), #changes size of facet x axis 
        strip.text.y = element_text(size = 18, face = "bold")) + #changes size of facet y axis 
  xlab('Dimension 1 (67.5%)') + ylab('Dimension 2 (9.5%)')  #changing axis labels
# Out:
# plot without title

# %% [markdown]
# The proteomics data looks the most promising, so let's just zoom in on that biomarker.

# %%
options(repr.plot.width=12, repr.plot.height=7) #changing size
condensate_plot = ggplot(data = full_eigenvector_df %>%
           filter(Biomarker == "Protein"), aes(x = PC1, y = PC2, color = Condensate)) + 
  geom_point(size = 2) + 
  stat_ellipse(level = 0.95) + # 95% confidence ellipses

  theme_light() + 
  theme(axis.text.x = element_text(vjust = 0.5), #rotating x labels/ moving x labels slightly to the left
        axis.line = element_line(colour="black"), #making x and y axes black
        axis.text = element_text(size = 13), #changing size of x axis labels
        axis.title = element_text(face = "bold", size = rel(1.7)), #changes axis titles
        legend.title = element_text(face = 'bold', size = 17), #changes legend title
        legend.text = element_text(size = 14), #changes legend text
        legend.position = 'bottom',
        legend.background = element_rect(colour = 'black', fill = 'white', linetype = 'solid'),
        strip.text.x = element_text(size = 18, face = "bold"), #changes size of facet x axis 
        strip.text.y = element_text(size = 18, face = "bold")) + #changes size of facet y axis 
  xlab('Dimension 1 (67.5%)') + ylab('Dimension 2 (9.5%)')  #changing axis labels 

burn_condition_plot = ggplot(data = full_eigenvector_df %>%
           filter(Biomarker == "Protein"), aes(x = PC1, y = PC2, color = Burn_Condition)) + 
  geom_point(size = 2) + 
  stat_ellipse(level = 0.95) + # 95% confidence ellipses

  theme_light() + 
  theme(axis.text.x = element_text(vjust = 0.5), #rotating x labels/ moving x labels slightly to the left
        axis.line = element_line(colour="black"), #making x and y axes black
        axis.text = element_text(size = 13), #changing size of x axis labels
        axis.title = element_text(face = "bold", size = rel(1.7)), #changes axis titles
        legend.title = element_text(face = 'bold', size = 17), #changes legend title
        legend.text = element_text(size = 14), #changes legend text
        legend.position = 'bottom',
        legend.background = element_rect(colour = 'black', fill = 'white', linetype = 'solid'),
        strip.text.x = element_text(size = 18, face = "bold"), #changes size of facet x axis 
        strip.text.y = element_text(size = 18, face = "bold")) + #changes size of facet y axis 
  xlab('Dimension 1 (67.5%)') + ylab('Dimension 2 (9.5%)')  #changing axis labels

# %%
options(repr.plot.width = 16, repr.plot.height = 7) #changing size
plot_grid(condensate_plot, burn_condition_plot)
# Out:
# plot without title
